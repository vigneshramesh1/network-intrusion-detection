# %%
# !pip install fancyimpute
# !pip install pandas
# Out:
# Requirement already satisfied: fancyimpute in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (0.7.0)
# Requirement already satisfied: knnimpute>=0.1.0 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from fancyimpute) (0.1.0)
# Requirement already satisfied: scikit-learn>=0.24.2 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from fancyimpute) (1.4.1.post1)
# Requirement already satisfied: cvxpy in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from fancyimpute) (1.4.2)
# Requirement already satisfied: cvxopt in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from fancyimpute) (1.3.2)
# Requirement already satisfied: pytest in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from fancyimpute) (8.1.1)
# Requirement already satisfied: nose in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from fancyimpute) (1.3.7)
# Requirement already satisfied: six in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from knnimpute>=0.1.0->fancyimpute) (1.16.0)
# Requirement already satisfied: numpy>=1.10 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from knnimpute>=0.1.0->fancyimpute) (1.24.1)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from scikit-learn>=0.24.2->fancyimpute) (1.11.4)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from scikit-learn>=0.24.2->fancyimpute) (1.4.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from scikit-learn>=0.24.2->fancyimpute) (3.4.0)
# Requirement already satisfied: osqp>=0.6.2 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from cvxpy->fancyimpute) (0.6.5)
# Requirement already satisfied: ecos>=2 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from cvxpy->fancyimpute) (2.0.13)
# Requirement already satisfied: clarabel>=0.5.0 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from cvxpy->fancyimpute) (0.7.1)
# Requirement already satisfied: scs>=3.0 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from cvxpy->fancyimpute) (3.2.4.post1)
# Requirement already satisfied: pybind11 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from cvxpy->fancyimpute) (2.12.0)
# Requirement already satisfied: iniconfig in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from pytest->fancyimpute) (2.0.0)
# Requirement already satisfied: packaging in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from pytest->fancyimpute) (24.0)
# Requirement already satisfied: pluggy<2.0,>=1.4 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from pytest->fancyimpute) (1.4.0)
# Requirement already satisfied: exceptiongroup>=1.0.0rc8 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from pytest->fancyimpute) (1.2.0)
# Requirement already satisfied: tomli>=1 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from pytest->fancyimpute) (2.0.1)
# Requirement already satisfied: colorama in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from pytest->fancyimpute) (0.4.6)
# Requirement already satisfied: qdldl in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from osqp>=0.6.2->cvxpy->fancyimpute) (0.1.7.post1)
# Requirement already satisfied: pandas in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (2.2.1)
# Requirement already satisfied: numpy<2,>=1.22.4 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from pandas) (1.24.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: six>=1.5 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn.decomposition import PCA
from sklearn.feature_selection import mutual_info_classif

# %%
# Read the data
df = pd.read_csv('C:/Users/user/Downloads/517/csv_preprocessed.csv')
print(df.shape)
# Out:
# (1215675, 63)

# %%
# Define features and target
X = df.drop(columns=['Attack Type'])
y = df['Attack Type']

# %%
# Perform mutual information feature selection
mutual_info_arr = mutual_info_classif(X, y)
top_features = X.columns[np.argsort(mutual_info_arr)[::-1][:15]]
X_selected = X[top_features]

# %%
# Perform PCA
pca = PCA(n_components=15)
X_pca = pca.fit_transform(X_selected)

# %%
# Define the parameter grid
param_grid = {
    'n_estimators': [10, 50, 100],
    'max_depth': [None, 10, 20],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4],
    'bootstrap': [True, False],
    'criterion': ['gini', 'entropy']
}

# %%
# Initialize GridSearchCV
grid_search = GridSearchCV(estimator=RandomForestClassifier(random_state=42), param_grid=param_grid, cv=5, scoring='accuracy', verbose=10)

# %%
# Perform Grid Search
grid_search.fit(X_pca, y)
# Out:
# Fitting 5 folds for each of 324 candidates, totalling 1620 fits
# [CV 1/5; 1/324] START bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=10
# [CV 1/5; 1/324] END bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=10;, score=0.989 total time=   7.0s
# [CV 2/5; 1/324] START bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=10
# [CV 2/5; 1/324] END bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=10;, score=0.989 total time=   7.5s
# [CV 3/5; 1/324] START bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=10
# [CV 3/5; 1/324] END bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=10;, score=0.985 total time=   7.3s
# [CV 4/5; 1/324] START bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=10
# [CV 4/5; 1/324] END bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=10;, score=0.997 total time=   7.0s
# [CV 5/5; 1/324] START bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=10
# [CV 5/5; 1/324] END bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=10;, score=0.981 total time=   6.9s
# [CV 1/5; 2/324] START bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=50
# [CV 1/5; 2/324] END bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=50;, score=0.988 total time=  34.5s
# [CV 2/5; 2/324] START bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=50
# [CV 2/5; 2/324] END bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=50;, score=0.990 total time=  36.7s
# [CV 3/5; 2/324] START bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=50
# [CV 3/5; 2/324] END bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=50;, score=0.986 total time=  36.8s
# [CV 4/5; 2/324] START bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=50
# [CV 4/5; 2/324] END bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=50;, score=0.997 total time=  35.1s
# [CV 5/5; 2/324] START bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=50
# [CV 5/5; 2/324] END bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=50;, score=0.997 total time=  34.4s
# [CV 1/5; 3/324] START bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=100
# [CV 1/5; 3/324] END bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.989 total time= 1.2min
# [CV 2/5; 3/324] START bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=100
# [CV 2/5; 3/324] END bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.990 total time= 1.2min
# [CV 3/5; 3/324] START bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=100
# [CV 3/5; 3/324] END bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.986 total time= 1.2min
# [CV 4/5; 3/324] START bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=100
# [CV 4/5; 3/324] END bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.997 total time= 1.2min
# [CV 5/5; 3/324] START bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=100
# [CV 5/5; 3/324] END bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.997 total time= 1.2min
# [CV 1/5; 4/324] START bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=10
# [CV 1/5; 4/324] END bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=10;, score=0.993 total time=   7.1s
# [CV 2/5; 4/324] START bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=10
# [CV 2/5; 4/324] END bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=10;, score=0.989 total time=   7.2s
# [CV 3/5; 4/324] START bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=10
# [CV 3/5; 4/324] END bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=10;, score=0.985 total time=   7.5s
# [CV 4/5; 4/324] START bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=10
# [CV 4/5; 4/324] END bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=10;, score=0.997 total time=   7.0s
# [CV 5/5; 4/324] START bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=10
# [CV 5/5; 4/324] END bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=10;, score=0.988 total time=   7.0s
# [CV 1/5; 5/324] START bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=50
# [CV 1/5; 5/324] END bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=50;, score=0.991 total time=  34.4s
# [CV 2/5; 5/324] START bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=50
# [CV 2/5; 5/324] END bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=50;, score=0.998 total time=  34.7s
# [CV 3/5; 5/324] START bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=50
# [CV 3/5; 5/324] END bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=50;, score=0.986 total time=  34.8s
# [CV 4/5; 5/324] START bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=50
# [CV 4/5; 5/324] END bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=50;, score=0.997 total time=  33.5s
# [CV 5/5; 5/324] START bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=50
# [CV 5/5; 5/324] END bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=50;, score=0.997 total time=  33.4s
# [CV 1/5; 6/324] START bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=100
# [CV 1/5; 6/324] END bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=100;, score=0.992 total time= 1.2min
# [CV 2/5; 6/324] START bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=100
# [CV 2/5; 6/324] END bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=100;, score=0.990 total time= 1.2min
# [CV 3/5; 6/324] START bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=100
# [CV 3/5; 6/324] END bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=100;, score=0.986 total time= 1.2min
# [CV 4/5; 6/324] START bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=100
# [CV 4/5; 6/324] END bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=100;, score=0.997 total time= 1.2min
# [CV 5/5; 6/324] START bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=100
# [CV 5/5; 6/324] END bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=100;, score=0.997 total time= 1.1min
# [CV 1/5; 7/324] START bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=10
# [CV 1/5; 7/324] END bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=10;, score=0.993 total time=   7.1s
# [CV 2/5; 7/324] START bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=10
# [CV 2/5; 7/324] END bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=10;, score=0.989 total time=   7.2s
# [CV 3/5; 7/324] START bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=10
# [CV 3/5; 7/324] END bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=10;, score=0.985 total time=   7.0s
# [CV 4/5; 7/324] START bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=10
# [CV 4/5; 7/324] END bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=10;, score=0.997 total time=   7.3s
# [CV 5/5; 7/324] START bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=10
# [CV 5/5; 7/324] END bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=10;, score=0.997 total time=   6.9s
# [CV 1/5; 8/324] START bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=50
# [CV 1/5; 8/324] END bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=50;, score=0.991 total time=  36.5s
# [CV 2/5; 8/324] START bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=50
# [CV 2/5; 8/324] END bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=50;, score=0.990 total time=  40.3s
# [CV 3/5; 8/324] START bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=50
# [CV 3/5; 8/324] END bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=50;, score=0.986 total time=  58.0s
# [CV 4/5; 8/324] START bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=50
# [CV 4/5; 8/324] END bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=50;, score=0.997 total time=  56.5s
# [CV 5/5; 8/324] START bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=50
# [CV 5/5; 8/324] END bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=50;, score=0.997 total time=  55.1s
# [CV 1/5; 9/324] START bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=100
# [CV 1/5; 9/324] END bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=100;, score=0.991 total time= 1.9min
# [CV 2/5; 9/324] START bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=100
# [CV 2/5; 9/324] END bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=100;, score=0.997 total time= 2.0min
# [CV 3/5; 9/324] START bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=100
# [CV 3/5; 9/324] END bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=100;, score=0.986 total time= 2.0min
# [CV 4/5; 9/324] START bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=100
# [CV 4/5; 9/324] END bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=100;, score=0.997 total time= 1.9min
# [CV 5/5; 9/324] START bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=100
# [CV 5/5; 9/324] END bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=100;, score=0.997 total time= 1.9min
# [CV 1/5; 10/324] START bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=10
# [CV 1/5; 10/324] END bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=10;, score=0.990 total time=  11.7s
# [CV 2/5; 10/324] START bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=10
# [CV 2/5; 10/324] END bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=10;, score=0.997 total time=  12.4s
# [CV 3/5; 10/324] START bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=10
# [CV 3/5; 10/324] END bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=10;, score=0.993 total time=  12.1s
# [CV 4/5; 10/324] START bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=10
# [CV 4/5; 10/324] END bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=10;, score=0.997 total time=  11.5s
# [CV 5/5; 10/324] START bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=10
# [CV 5/5; 10/324] END bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=10;, score=0.988 total time=  11.2s
# [CV 1/5; 11/324] START bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=50
# [CV 1/5; 11/324] END bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=50;, score=0.991 total time=  58.2s
# [CV 2/5; 11/324] START bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=50
# [CV 2/5; 11/324] END bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=50;, score=0.998 total time=  59.6s
# [CV 3/5; 11/324] START bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=50
# [CV 3/5; 11/324] END bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=50;, score=0.986 total time=  58.7s
# [CV 4/5; 11/324] START bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=50
# [CV 4/5; 11/324] END bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=50;, score=0.997 total time=  56.6s
# [CV 5/5; 11/324] START bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=50
# [CV 5/5; 11/324] END bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=50;, score=0.997 total time=  55.3s
# [CV 1/5; 12/324] START bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=100
# [CV 1/5; 12/324] END bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=0.991 total time= 1.9min
# [CV 2/5; 12/324] START bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=100
# [CV 2/5; 12/324] END bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=0.990 total time= 2.0min
# [CV 3/5; 12/324] START bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=100
# [CV 3/5; 12/324] END bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=0.986 total time= 2.0min
# [CV 4/5; 12/324] START bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=100
# [CV 4/5; 12/324] END bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=0.997 total time= 1.9min
# [CV 5/5; 12/324] START bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=100
# [CV 5/5; 12/324] END bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=0.997 total time= 1.9min
# [CV 1/5; 13/324] START bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=10
# [CV 1/5; 13/324] END bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=10;, score=0.990 total time=  11.9s
# [CV 2/5; 13/324] START bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=10
# [CV 2/5; 13/324] END bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=10;, score=0.997 total time=  12.1s
# [CV 3/5; 13/324] START bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=10
# [CV 3/5; 13/324] END bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=10;, score=0.985 total time=  11.8s
# [CV 4/5; 13/324] START bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=10
# [CV 4/5; 13/324] END bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=10;, score=0.997 total time=  11.8s
# [CV 5/5; 13/324] START bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=10
# [CV 5/5; 13/324] END bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=10;, score=0.997 total time=  11.2s
# [CV 1/5; 14/324] START bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=50
# [CV 1/5; 14/324] END bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=50;, score=0.989 total time=  59.0s
# [CV 2/5; 14/324] START bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=50
# [CV 2/5; 14/324] END bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=50;, score=0.990 total time= 1.0min
# [CV 3/5; 14/324] START bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=50
# [CV 3/5; 14/324] END bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=50;, score=0.986 total time=  58.2s
# [CV 4/5; 14/324] START bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=50
# [CV 4/5; 14/324] END bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=50;, score=0.997 total time=  57.4s
# [CV 5/5; 14/324] START bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=50
# [CV 5/5; 14/324] END bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=50;, score=0.997 total time=  56.0s
# [CV 1/5; 15/324] START bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=100
# [CV 1/5; 15/324] END bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=100;, score=0.990 total time= 2.0min
# [CV 2/5; 15/324] START bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=100
# [CV 2/5; 15/324] END bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=100;, score=0.990 total time= 2.0min
# [CV 3/5; 15/324] START bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=100
# [CV 3/5; 15/324] END bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=100;, score=0.986 total time= 2.0min
# [CV 4/5; 15/324] START bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=100
# [CV 4/5; 15/324] END bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=100;, score=0.997 total time= 1.9min
# [CV 5/5; 15/324] START bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=100
# [CV 5/5; 15/324] END bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=100;, score=0.997 total time= 1.8min
# [CV 1/5; 16/324] START bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=10
# [CV 1/5; 16/324] END bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=10;, score=0.989 total time=  11.3s
# [CV 2/5; 16/324] START bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=10
# [CV 2/5; 16/324] END bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=10;, score=0.989 total time=  12.0s
# [CV 3/5; 16/324] START bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=10
# [CV 3/5; 16/324] END bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=10;, score=0.985 total time=  11.5s
# [CV 4/5; 16/324] START bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=10
# [CV 4/5; 16/324] END bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=10;, score=0.997 total time=  11.2s
# [CV 5/5; 16/324] START bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=10
# [CV 5/5; 16/324] END bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=10;, score=0.997 total time=  10.2s
# [CV 1/5; 17/324] START bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=50
# [CV 1/5; 17/324] END bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=50;, score=0.991 total time=  54.6s
# [CV 2/5; 17/324] START bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=50
# [CV 2/5; 17/324] END bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=50;, score=0.990 total time=  58.4s
# [CV 3/5; 17/324] START bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=50
# [CV 3/5; 17/324] END bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=50;, score=0.986 total time=  57.7s
# [CV 4/5; 17/324] START bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=50
# [CV 4/5; 17/324] END bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=50;, score=0.997 total time=  55.6s
# [CV 5/5; 17/324] START bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=50
# [CV 5/5; 17/324] END bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=50;, score=0.997 total time=  55.2s
# [CV 1/5; 18/324] START bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=100
# [CV 1/5; 18/324] END bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=100;, score=0.989 total time= 1.9min
# [CV 2/5; 18/324] START bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=100
# [CV 2/5; 18/324] END bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=100;, score=0.998 total time= 2.0min
# [CV 3/5; 18/324] START bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=100
# [CV 3/5; 18/324] END bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=100;, score=0.986 total time= 2.0min
# [CV 4/5; 18/324] START bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=100
# [CV 4/5; 18/324] END bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=100;, score=0.997 total time= 1.9min
# [CV 5/5; 18/324] START bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=100
# [CV 5/5; 18/324] END bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=100;, score=0.997 total time= 1.9min
# [CV 1/5; 19/324] START bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=10
# [CV 1/5; 19/324] END bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=10;, score=0.990 total time=  11.5s
# [CV 2/5; 19/324] START bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=10
# [CV 2/5; 19/324] END bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=10;, score=0.990 total time=  12.1s
# [CV 3/5; 19/324] START bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=10
# [CV 3/5; 19/324] END bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=10;, score=0.985 total time=  11.6s
# [CV 4/5; 19/324] START bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=10
# [CV 4/5; 19/324] END bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=10;, score=0.997 total time=  11.3s
# [CV 5/5; 19/324] START bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=10
# [CV 5/5; 19/324] END bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=10;, score=0.980 total time=  11.1s
# [CV 1/5; 20/324] START bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=50
# [CV 1/5; 20/324] END bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=50;, score=0.990 total time=  57.6s
# [CV 2/5; 20/324] START bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=50
# [CV 2/5; 20/324] END bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=50;, score=0.997 total time=  59.1s
# [CV 3/5; 20/324] START bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=50
# [CV 3/5; 20/324] END bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=50;, score=0.985 total time=  58.1s
# [CV 4/5; 20/324] START bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=50
# [CV 4/5; 20/324] END bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=50;, score=0.997 total time=  56.2s
# [CV 5/5; 20/324] START bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=50
# [CV 5/5; 20/324] END bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=50;, score=0.997 total time=  55.1s
# [CV 1/5; 21/324] START bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=100
# [CV 1/5; 21/324] END bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=100;, score=0.990 total time= 1.9min
# [CV 2/5; 21/324] START bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=100
# [CV 2/5; 21/324] END bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=100;, score=0.990 total time= 2.0min
# [CV 3/5; 21/324] START bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=100
# [CV 3/5; 21/324] END bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=100;, score=0.986 total time= 2.0min
# [CV 4/5; 21/324] START bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=100
# [CV 4/5; 21/324] END bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=100;, score=0.997 total time= 1.9min
# [CV 5/5; 21/324] START bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=100
# [CV 5/5; 21/324] END bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=100;, score=0.997 total time= 1.9min
# [CV 1/5; 22/324] START bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=10
# [CV 1/5; 22/324] END bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=10;, score=0.990 total time=  11.8s
# [CV 2/5; 22/324] START bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=10
# [CV 2/5; 22/324] END bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=10;, score=0.990 total time=  12.0s
# [CV 3/5; 22/324] START bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=10
# [CV 3/5; 22/324] END bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=10;, score=0.985 total time=  11.6s
# [CV 4/5; 22/324] START bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=10
# [CV 4/5; 22/324] END bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=10;, score=0.997 total time=  11.4s
# [CV 5/5; 22/324] START bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=10
# [CV 5/5; 22/324] END bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=10;, score=0.980 total time=  10.6s
# [CV 1/5; 23/324] START bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=50
# [CV 1/5; 23/324] END bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=50;, score=0.990 total time=  55.9s
# [CV 2/5; 23/324] START bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=50
# [CV 2/5; 23/324] END bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=50;, score=0.997 total time=  58.7s
# [CV 3/5; 23/324] START bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=50
# [CV 3/5; 23/324] END bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=50;, score=0.985 total time=  58.6s
# [CV 4/5; 23/324] START bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=50
# [CV 4/5; 23/324] END bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=50;, score=0.997 total time=  56.1s
# [CV 5/5; 23/324] START bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=50
# [CV 5/5; 23/324] END bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=50;, score=0.997 total time=  54.5s
# [CV 1/5; 24/324] START bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=100
# [CV 1/5; 24/324] END bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=100;, score=0.990 total time= 1.9min
# [CV 2/5; 24/324] START bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=100
# [CV 2/5; 24/324] END bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=100;, score=0.990 total time= 2.0min
# [CV 3/5; 24/324] START bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=100
# [CV 3/5; 24/324] END bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=100;, score=0.986 total time= 2.0min
# [CV 4/5; 24/324] START bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=100
# [CV 4/5; 24/324] END bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=100;, score=0.997 total time= 1.9min
# [CV 5/5; 24/324] START bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=100
# [CV 5/5; 24/324] END bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=100;, score=0.997 total time= 1.9min
# [CV 1/5; 25/324] START bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=10
# [CV 1/5; 25/324] END bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=10;, score=0.991 total time=  11.4s
# [CV 2/5; 25/324] START bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=10
# [CV 2/5; 25/324] END bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=10;, score=0.997 total time=  11.8s
# [CV 3/5; 25/324] START bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=10
# [CV 3/5; 25/324] END bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=10;, score=0.985 total time=  11.4s
# [CV 4/5; 25/324] START bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=10
# [CV 4/5; 25/324] END bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=10;, score=0.997 total time=  11.4s
# [CV 5/5; 25/324] START bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=10
# [CV 5/5; 25/324] END bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=10;, score=0.997 total time=  11.4s
# [CV 1/5; 26/324] START bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=50
# [CV 1/5; 26/324] END bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=50;, score=0.990 total time=  56.3s
# [CV 2/5; 26/324] START bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=50
# [CV 2/5; 26/324] END bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=50;, score=0.990 total time=  58.3s
# [CV 3/5; 26/324] START bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=50
# [CV 3/5; 26/324] END bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=50;, score=0.985 total time=  59.6s
# [CV 4/5; 26/324] START bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=50
# [CV 4/5; 26/324] END bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=50;, score=0.997 total time=  56.5s
# [CV 5/5; 26/324] START bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=50
# [CV 5/5; 26/324] END bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=50;, score=0.997 total time=  54.3s
# [CV 1/5; 27/324] START bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=100
# [CV 1/5; 27/324] END bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=100;, score=0.989 total time= 1.9min
# [CV 2/5; 27/324] START bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=100
# [CV 2/5; 27/324] END bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=100;, score=0.990 total time= 2.0min
# [CV 3/5; 27/324] START bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=100
# [CV 3/5; 27/324] END bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=100;, score=0.985 total time= 2.0min
# [CV 4/5; 27/324] START bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=100
# [CV 4/5; 27/324] END bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=100;, score=0.997 total time= 1.9min
# [CV 5/5; 27/324] START bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=100
# [CV 5/5; 27/324] END bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=100;, score=0.997 total time= 1.8min
# [CV 1/5; 28/324] START bootstrap=True, criterion=gini, max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=10
# [CV 1/5; 28/324] END bootstrap=True, criterion=gini, max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=10;, score=0.982 total time=   8.4s
# [CV 2/5; 28/324] START bootstrap=True, criterion=gini, max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=10
# [CV 2/5; 28/324] END bootstrap=True, criterion=gini, max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=10;, score=0.980 total time=   8.5s
# [CV 3/5; 28/324] START bootstrap=True, criterion=gini, max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=10
# [CV 3/5; 28/324] END bootstrap=True, criterion=gini, max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=10;, score=0.976 total time=   8.4s
# [CV 4/5; 28/324] START bootstrap=True, criterion=gini, max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=10
# [CV 4/5; 28/324] END bootstrap=True, criterion=gini, max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=10;, score=0.991 total time=   8.1s
# [CV 5/5; 28/324] START bootstrap=True, criterion=gini, max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=10
# [CV 5/5; 28/324] END bootstrap=True, criterion=gini, max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=10;, score=0.991 total time=   8.0s
# [CV 1/5; 29/324] START bootstrap=True, criterion=gini, max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=50
# [CV 1/5; 29/324] END bootstrap=True, criterion=gini, max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=50;, score=0.980 total time=  41.5s
# [CV 2/5; 29/324] START bootstrap=True, criterion=gini, max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=50
# [CV 2/5; 29/324] END bootstrap=True, criterion=gini, max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=50;, score=0.979 total time=  42.5s
# [CV 3/5; 29/324] START bootstrap=True, criterion=gini, max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=50
# [CV 3/5; 29/324] END bootstrap=True, criterion=gini, max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=50;, score=0.976 total time=  41.9s
# [CV 4/5; 29/324] START bootstrap=True, criterion=gini, max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=50
# [CV 4/5; 29/324] END bootstrap=True, criterion=gini, max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=50;, score=0.991 total time=  40.6s
# [CV 5/5; 29/324] START bootstrap=True, criterion=gini, max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=50
# [CV 5/5; 29/324] END bootstrap=True, criterion=gini, max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=50;, score=0.991 total time=  39.6s
# [CV 1/5; 30/324] START bootstrap=True, criterion=gini, max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=100
# [CV 1/5; 30/324] END bootstrap=True, criterion=gini, max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.980 total time= 1.4min
# [CV 2/5; 30/324] START bootstrap=True, criterion=gini, max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=100
# [CV 2/5; 30/324] END bootstrap=True, criterion=gini, max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.979 total time= 1.4min
# [CV 3/5; 30/324] START bootstrap=True, criterion=gini, max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=100
# [CV 3/5; 30/324] END bootstrap=True, criterion=gini, max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.976 total time= 1.4min
# [CV 4/5; 30/324] START bootstrap=True, criterion=gini, max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=100
# [CV 4/5; 30/324] END bootstrap=True, criterion=gini, max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.991 total time= 1.4min
# [CV 5/5; 30/324] START bootstrap=True, criterion=gini, max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=100
# [CV 5/5; 30/324] END bootstrap=True, criterion=gini, max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.991 total time= 1.3min
# [CV 1/5; 31/324] START bootstrap=True, criterion=gini, max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=10
# [CV 1/5; 31/324] END bootstrap=True, criterion=gini, max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=10;, score=0.983 total time=   8.2s
# [CV 2/5; 31/324] START bootstrap=True, criterion=gini, max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=10
# [CV 2/5; 31/324] END bootstrap=True, criterion=gini, max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=10;, score=0.980 total time=   8.5s
# [CV 3/5; 31/324] START bootstrap=True, criterion=gini, max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=10
# [CV 3/5; 31/324] END bootstrap=True, criterion=gini, max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=10;, score=0.984 total time=   8.5s
# [CV 4/5; 31/324] START bootstrap=True, criterion=gini, max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=10
# [CV 4/5; 31/324] END bootstrap=True, criterion=gini, max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=10;, score=0.991 total time=   8.5s
# [CV 5/5; 31/324] START bootstrap=True, criterion=gini, max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=10
# [CV 5/5; 31/324] END bootstrap=True, criterion=gini, max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=10;, score=0.991 total time=   8.2s
# [CV 1/5; 32/324] START bootstrap=True, criterion=gini, max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=50
# [CV 1/5; 32/324] END bootstrap=True, criterion=gini, max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=50;, score=0.981 total time=  41.6s
# [CV 2/5; 32/324] START bootstrap=True, criterion=gini, max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=50
# [CV 2/5; 32/324] END bootstrap=True, criterion=gini, max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=50;, score=0.978 total time=  43.1s
# [CV 3/5; 32/324] START bootstrap=True, criterion=gini, max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=50
# [CV 3/5; 32/324] END bootstrap=True, criterion=gini, max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=50;, score=0.976 total time=  42.7s
# [CV 4/5; 32/324] START bootstrap=True, criterion=gini, max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=50
# [CV 4/5; 32/324] END bootstrap=True, criterion=gini, max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=50;, score=0.991 total time=  41.3s
# [CV 5/5; 32/324] START bootstrap=True, criterion=gini, max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=50
# [CV 5/5; 32/324] END bootstrap=True, criterion=gini, max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=50;, score=0.991 total time=  39.1s
# [CV 1/5; 33/324] START bootstrap=True, criterion=gini, max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=100
# [CV 1/5; 33/324] END bootstrap=True, criterion=gini, max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=100;, score=0.980 total time= 1.4min
# [CV 2/5; 33/324] START bootstrap=True, criterion=gini, max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=100
# [CV 2/5; 33/324] END bootstrap=True, criterion=gini, max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=100;, score=0.979 total time= 1.4min
# [CV 3/5; 33/324] START bootstrap=True, criterion=gini, max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=100
# [CV 3/5; 33/324] END bootstrap=True, criterion=gini, max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=100;, score=0.976 total time= 1.4min
# [CV 4/5; 33/324] START bootstrap=True, criterion=gini, max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=100
# [CV 4/5; 33/324] END bootstrap=True, criterion=gini, max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=100;, score=0.991 total time= 1.4min
# [CV 5/5; 33/324] START bootstrap=True, criterion=gini, max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=100
# [CV 5/5; 33/324] END bootstrap=True, criterion=gini, max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=100;, score=0.991 total time= 1.3min
# [CV 1/5; 34/324] START bootstrap=True, criterion=gini, max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=10
# [CV 1/5; 34/324] END bootstrap=True, criterion=gini, max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=10;, score=0.979 total time=   8.1s
# [CV 2/5; 34/324] START bootstrap=True, criterion=gini, max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=10
# [CV 2/5; 34/324] END bootstrap=True, criterion=gini, max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=10;, score=0.977 total time=   8.5s
# ...
# [CV 3/5; 314/324] END bootstrap=False, criterion=entropy, max_depth=20, min_samples_leaf=2, min_samples_split=10, n_estimators=50;, score=0.994 total time= 2.0min
# [CV 4/5; 314/324] START bootstrap=False, criterion=entropy, max_depth=20, min_samples_leaf=2, min_samples_split=10, n_estimators=50
# [CV 4/5; 314/324] END bootstrap=False, criterion=entropy, max_depth=20, min_samples_leaf=2, min_samples_split=10, n_estimators=50;, score=0.997 total time= 1.9min
# [CV 5/5; 314/324] START bootstrap=False, criterion=entropy, max_depth=20, min_samples_leaf=2, min_samples_split=10, n_estimators=50
# [CV 5/5; 314/324] END bootstrap=False, criterion=entropy, max_depth=20, min_samples_leaf=2, min_samples_split=10, n_estimators=50;, score=0.997 total time= 1.9min
# [CV 1/5; 315/324] START bootstrap=False, criterion=entropy, max_depth=20, min_samples_leaf=2, min_samples_split=10, n_estimators=100
# [CV 1/5; 315/324] END bootstrap=False, criterion=entropy, max_depth=20, min_samples_leaf=2, min_samples_split=10, n_estimators=100;, score=0.990 total time= 3.8min
# [CV 2/5; 315/324] START bootstrap=False, criterion=entropy, max_depth=20, min_samples_leaf=2, min_samples_split=10, n_estimators=100
# [CV 2/5; 315/324] END bootstrap=False, criterion=entropy, max_depth=20, min_samples_leaf=2, min_samples_split=10, n_estimators=100;, score=0.990 total time= 4.0min
# [CV 3/5; 315/324] START bootstrap=False, criterion=entropy, max_depth=20, min_samples_leaf=2, min_samples_split=10, n_estimators=100
# [CV 3/5; 315/324] END bootstrap=False, criterion=entropy, max_depth=20, min_samples_leaf=2, min_samples_split=10, n_estimators=100;, score=0.986 total time= 4.0min
# [CV 4/5; 315/324] START bootstrap=False, criterion=entropy, max_depth=20, min_samples_leaf=2, min_samples_split=10, n_estimators=100
# [CV 4/5; 315/324] END bootstrap=False, criterion=entropy, max_depth=20, min_samples_leaf=2, min_samples_split=10, n_estimators=100;, score=0.997 total time= 3.9min
# [CV 5/5; 315/324] START bootstrap=False, criterion=entropy, max_depth=20, min_samples_leaf=2, min_samples_split=10, n_estimators=100
# [CV 5/5; 315/324] END bootstrap=False, criterion=entropy, max_depth=20, min_samples_leaf=2, min_samples_split=10, n_estimators=100;, score=0.997 total time= 3.8min
# [CV 1/5; 316/324] START bootstrap=False, criterion=entropy, max_depth=20, min_samples_leaf=4, min_samples_split=2, n_estimators=10
# [CV 1/5; 316/324] END bootstrap=False, criterion=entropy, max_depth=20, min_samples_leaf=4, min_samples_split=2, n_estimators=10;, score=0.991 total time=  23.3s
# [CV 2/5; 316/324] START bootstrap=False, criterion=entropy, max_depth=20, min_samples_leaf=4, min_samples_split=2, n_estimators=10
# [CV 2/5; 316/324] END bootstrap=False, criterion=entropy, max_depth=20, min_samples_leaf=4, min_samples_split=2, n_estimators=10;, score=0.989 total time=  24.9s
# [CV 3/5; 316/324] START bootstrap=False, criterion=entropy, max_depth=20, min_samples_leaf=4, min_samples_split=2, n_estimators=10
# [CV 3/5; 316/324] END bootstrap=False, criterion=entropy, max_depth=20, min_samples_leaf=4, min_samples_split=2, n_estimators=10;, score=0.985 total time=  23.6s
# [CV 4/5; 316/324] START bootstrap=False, criterion=entropy, max_depth=20, min_samples_leaf=4, min_samples_split=2, n_estimators=10
# [CV 4/5; 316/324] END bootstrap=False, criterion=entropy, max_depth=20, min_samples_leaf=4, min_samples_split=2, n_estimators=10;, score=0.997 total time=  23.5s
# [CV 5/5; 316/324] START bootstrap=False, criterion=entropy, max_depth=20, min_samples_leaf=4, min_samples_split=2, n_estimators=10
# [CV 5/5; 316/324] END bootstrap=False, criterion=entropy, max_depth=20, min_samples_leaf=4, min_samples_split=2, n_estimators=10;, score=0.997 total time=  22.7s
# [CV 1/5; 317/324] START bootstrap=False, criterion=entropy, max_depth=20, min_samples_leaf=4, min_samples_split=2, n_estimators=50
# [CV 1/5; 317/324] END bootstrap=False, criterion=entropy, max_depth=20, min_samples_leaf=4, min_samples_split=2, n_estimators=50;, score=0.992 total time= 1.9min
# [CV 2/5; 317/324] START bootstrap=False, criterion=entropy, max_depth=20, min_samples_leaf=4, min_samples_split=2, n_estimators=50
# [CV 2/5; 317/324] END bootstrap=False, criterion=entropy, max_depth=20, min_samples_leaf=4, min_samples_split=2, n_estimators=50;, score=0.990 total time= 2.0min
# [CV 3/5; 317/324] START bootstrap=False, criterion=entropy, max_depth=20, min_samples_leaf=4, min_samples_split=2, n_estimators=50
# [CV 3/5; 317/324] END bootstrap=False, criterion=entropy, max_depth=20, min_samples_leaf=4, min_samples_split=2, n_estimators=50;, score=0.986 total time= 2.0min
# [CV 4/5; 317/324] START bootstrap=False, criterion=entropy, max_depth=20, min_samples_leaf=4, min_samples_split=2, n_estimators=50
# [CV 4/5; 317/324] END bootstrap=False, criterion=entropy, max_depth=20, min_samples_leaf=4, min_samples_split=2, n_estimators=50;, score=0.997 total time= 1.9min
# [CV 5/5; 317/324] START bootstrap=False, criterion=entropy, max_depth=20, min_samples_leaf=4, min_samples_split=2, n_estimators=50
# [CV 5/5; 317/324] END bootstrap=False, criterion=entropy, max_depth=20, min_samples_leaf=4, min_samples_split=2, n_estimators=50;, score=0.997 total time= 1.9min
# [CV 1/5; 318/324] START bootstrap=False, criterion=entropy, max_depth=20, min_samples_leaf=4, min_samples_split=2, n_estimators=100
# [CV 1/5; 318/324] END bootstrap=False, criterion=entropy, max_depth=20, min_samples_leaf=4, min_samples_split=2, n_estimators=100;, score=0.992 total time= 3.9min
# [CV 2/5; 318/324] START bootstrap=False, criterion=entropy, max_depth=20, min_samples_leaf=4, min_samples_split=2, n_estimators=100
# [CV 2/5; 318/324] END bootstrap=False, criterion=entropy, max_depth=20, min_samples_leaf=4, min_samples_split=2, n_estimators=100;, score=0.990 total time= 4.0min
# [CV 3/5; 318/324] START bootstrap=False, criterion=entropy, max_depth=20, min_samples_leaf=4, min_samples_split=2, n_estimators=100
# [CV 3/5; 318/324] END bootstrap=False, criterion=entropy, max_depth=20, min_samples_leaf=4, min_samples_split=2, n_estimators=100;, score=0.986 total time= 4.0min
# [CV 4/5; 318/324] START bootstrap=False, criterion=entropy, max_depth=20, min_samples_leaf=4, min_samples_split=2, n_estimators=100
# [CV 4/5; 318/324] END bootstrap=False, criterion=entropy, max_depth=20, min_samples_leaf=4, min_samples_split=2, n_estimators=100;, score=0.997 total time= 3.9min
# [CV 5/5; 318/324] START bootstrap=False, criterion=entropy, max_depth=20, min_samples_leaf=4, min_samples_split=2, n_estimators=100
# [CV 5/5; 318/324] END bootstrap=False, criterion=entropy, max_depth=20, min_samples_leaf=4, min_samples_split=2, n_estimators=100;, score=0.997 total time= 3.8min
# [CV 1/5; 319/324] START bootstrap=False, criterion=entropy, max_depth=20, min_samples_leaf=4, min_samples_split=5, n_estimators=10
# [CV 1/5; 319/324] END bootstrap=False, criterion=entropy, max_depth=20, min_samples_leaf=4, min_samples_split=5, n_estimators=10;, score=0.991 total time=  23.5s
# [CV 2/5; 319/324] START bootstrap=False, criterion=entropy, max_depth=20, min_samples_leaf=4, min_samples_split=5, n_estimators=10
# [CV 2/5; 319/324] END bootstrap=False, criterion=entropy, max_depth=20, min_samples_leaf=4, min_samples_split=5, n_estimators=10;, score=0.989 total time=  24.5s
# [CV 3/5; 319/324] START bootstrap=False, criterion=entropy, max_depth=20, min_samples_leaf=4, min_samples_split=5, n_estimators=10
# [CV 3/5; 319/324] END bootstrap=False, criterion=entropy, max_depth=20, min_samples_leaf=4, min_samples_split=5, n_estimators=10;, score=0.985 total time=  24.0s
# [CV 4/5; 319/324] START bootstrap=False, criterion=entropy, max_depth=20, min_samples_leaf=4, min_samples_split=5, n_estimators=10
# [CV 4/5; 319/324] END bootstrap=False, criterion=entropy, max_depth=20, min_samples_leaf=4, min_samples_split=5, n_estimators=10;, score=0.997 total time=  23.5s
# [CV 5/5; 319/324] START bootstrap=False, criterion=entropy, max_depth=20, min_samples_leaf=4, min_samples_split=5, n_estimators=10
# [CV 5/5; 319/324] END bootstrap=False, criterion=entropy, max_depth=20, min_samples_leaf=4, min_samples_split=5, n_estimators=10;, score=0.997 total time=  23.1s
# [CV 1/5; 320/324] START bootstrap=False, criterion=entropy, max_depth=20, min_samples_leaf=4, min_samples_split=5, n_estimators=50
# [CV 1/5; 320/324] END bootstrap=False, criterion=entropy, max_depth=20, min_samples_leaf=4, min_samples_split=5, n_estimators=50;, score=0.992 total time= 1.9min
# [CV 2/5; 320/324] START bootstrap=False, criterion=entropy, max_depth=20, min_samples_leaf=4, min_samples_split=5, n_estimators=50
# [CV 2/5; 320/324] END bootstrap=False, criterion=entropy, max_depth=20, min_samples_leaf=4, min_samples_split=5, n_estimators=50;, score=0.990 total time= 2.0min
# [CV 3/5; 320/324] START bootstrap=False, criterion=entropy, max_depth=20, min_samples_leaf=4, min_samples_split=5, n_estimators=50
# [CV 3/5; 320/324] END bootstrap=False, criterion=entropy, max_depth=20, min_samples_leaf=4, min_samples_split=5, n_estimators=50;, score=0.986 total time= 2.0min
# [CV 4/5; 320/324] START bootstrap=False, criterion=entropy, max_depth=20, min_samples_leaf=4, min_samples_split=5, n_estimators=50
# [CV 4/5; 320/324] END bootstrap=False, criterion=entropy, max_depth=20, min_samples_leaf=4, min_samples_split=5, n_estimators=50;, score=0.997 total time= 1.9min
# [CV 5/5; 320/324] START bootstrap=False, criterion=entropy, max_depth=20, min_samples_leaf=4, min_samples_split=5, n_estimators=50
# [CV 5/5; 320/324] END bootstrap=False, criterion=entropy, max_depth=20, min_samples_leaf=4, min_samples_split=5, n_estimators=50;, score=0.997 total time= 1.9min
# [CV 1/5; 321/324] START bootstrap=False, criterion=entropy, max_depth=20, min_samples_leaf=4, min_samples_split=5, n_estimators=100
# [CV 1/5; 321/324] END bootstrap=False, criterion=entropy, max_depth=20, min_samples_leaf=4, min_samples_split=5, n_estimators=100;, score=0.992 total time= 3.9min
# [CV 2/5; 321/324] START bootstrap=False, criterion=entropy, max_depth=20, min_samples_leaf=4, min_samples_split=5, n_estimators=100
# [CV 2/5; 321/324] END bootstrap=False, criterion=entropy, max_depth=20, min_samples_leaf=4, min_samples_split=5, n_estimators=100;, score=0.990 total time= 4.0min
# [CV 3/5; 321/324] START bootstrap=False, criterion=entropy, max_depth=20, min_samples_leaf=4, min_samples_split=5, n_estimators=100
# [CV 3/5; 321/324] END bootstrap=False, criterion=entropy, max_depth=20, min_samples_leaf=4, min_samples_split=5, n_estimators=100;, score=0.986 total time= 4.0min
# [CV 4/5; 321/324] START bootstrap=False, criterion=entropy, max_depth=20, min_samples_leaf=4, min_samples_split=5, n_estimators=100
# [CV 4/5; 321/324] END bootstrap=False, criterion=entropy, max_depth=20, min_samples_leaf=4, min_samples_split=5, n_estimators=100;, score=0.997 total time= 3.9min
# [CV 5/5; 321/324] START bootstrap=False, criterion=entropy, max_depth=20, min_samples_leaf=4, min_samples_split=5, n_estimators=100
# [CV 5/5; 321/324] END bootstrap=False, criterion=entropy, max_depth=20, min_samples_leaf=4, min_samples_split=5, n_estimators=100;, score=0.997 total time= 3.8min
# [CV 1/5; 322/324] START bootstrap=False, criterion=entropy, max_depth=20, min_samples_leaf=4, min_samples_split=10, n_estimators=10
# [CV 1/5; 322/324] END bootstrap=False, criterion=entropy, max_depth=20, min_samples_leaf=4, min_samples_split=10, n_estimators=10;, score=0.989 total time=  23.6s
# [CV 2/5; 322/324] START bootstrap=False, criterion=entropy, max_depth=20, min_samples_leaf=4, min_samples_split=10, n_estimators=10
# [CV 2/5; 322/324] END bootstrap=False, criterion=entropy, max_depth=20, min_samples_leaf=4, min_samples_split=10, n_estimators=10;, score=0.989 total time=  24.7s
# [CV 3/5; 322/324] START bootstrap=False, criterion=entropy, max_depth=20, min_samples_leaf=4, min_samples_split=10, n_estimators=10
# [CV 3/5; 322/324] END bootstrap=False, criterion=entropy, max_depth=20, min_samples_leaf=4, min_samples_split=10, n_estimators=10;, score=0.986 total time=  24.0s
# [CV 4/5; 322/324] START bootstrap=False, criterion=entropy, max_depth=20, min_samples_leaf=4, min_samples_split=10, n_estimators=10
# [CV 4/5; 322/324] END bootstrap=False, criterion=entropy, max_depth=20, min_samples_leaf=4, min_samples_split=10, n_estimators=10;, score=0.981 total time=  23.5s
# [CV 5/5; 322/324] START bootstrap=False, criterion=entropy, max_depth=20, min_samples_leaf=4, min_samples_split=10, n_estimators=10
# [CV 5/5; 322/324] END bootstrap=False, criterion=entropy, max_depth=20, min_samples_leaf=4, min_samples_split=10, n_estimators=10;, score=0.997 total time=  22.6s
# [CV 1/5; 323/324] START bootstrap=False, criterion=entropy, max_depth=20, min_samples_leaf=4, min_samples_split=10, n_estimators=50
# [CV 1/5; 323/324] END bootstrap=False, criterion=entropy, max_depth=20, min_samples_leaf=4, min_samples_split=10, n_estimators=50;, score=0.989 total time= 1.9min
# [CV 2/5; 323/324] START bootstrap=False, criterion=entropy, max_depth=20, min_samples_leaf=4, min_samples_split=10, n_estimators=50
# [CV 2/5; 323/324] END bootstrap=False, criterion=entropy, max_depth=20, min_samples_leaf=4, min_samples_split=10, n_estimators=50;, score=0.990 total time= 2.0min
# [CV 3/5; 323/324] START bootstrap=False, criterion=entropy, max_depth=20, min_samples_leaf=4, min_samples_split=10, n_estimators=50
# [CV 3/5; 323/324] END bootstrap=False, criterion=entropy, max_depth=20, min_samples_leaf=4, min_samples_split=10, n_estimators=50;, score=0.986 total time= 2.0min
# [CV 4/5; 323/324] START bootstrap=False, criterion=entropy, max_depth=20, min_samples_leaf=4, min_samples_split=10, n_estimators=50
# [CV 4/5; 323/324] END bootstrap=False, criterion=entropy, max_depth=20, min_samples_leaf=4, min_samples_split=10, n_estimators=50;, score=0.997 total time= 1.9min
# [CV 5/5; 323/324] START bootstrap=False, criterion=entropy, max_depth=20, min_samples_leaf=4, min_samples_split=10, n_estimators=50
# [CV 5/5; 323/324] END bootstrap=False, criterion=entropy, max_depth=20, min_samples_leaf=4, min_samples_split=10, n_estimators=50;, score=0.997 total time= 1.9min
# [CV 1/5; 324/324] START bootstrap=False, criterion=entropy, max_depth=20, min_samples_leaf=4, min_samples_split=10, n_estimators=100
# [CV 1/5; 324/324] END bootstrap=False, criterion=entropy, max_depth=20, min_samples_leaf=4, min_samples_split=10, n_estimators=100;, score=0.989 total time= 3.9min
# [CV 2/5; 324/324] START bootstrap=False, criterion=entropy, max_depth=20, min_samples_leaf=4, min_samples_split=10, n_estimators=100
# [CV 2/5; 324/324] END bootstrap=False, criterion=entropy, max_depth=20, min_samples_leaf=4, min_samples_split=10, n_estimators=100;, score=0.990 total time= 4.0min
# [CV 3/5; 324/324] START bootstrap=False, criterion=entropy, max_depth=20, min_samples_leaf=4, min_samples_split=10, n_estimators=100
# [CV 3/5; 324/324] END bootstrap=False, criterion=entropy, max_depth=20, min_samples_leaf=4, min_samples_split=10, n_estimators=100;, score=0.986 total time= 4.0min
# [CV 4/5; 324/324] START bootstrap=False, criterion=entropy, max_depth=20, min_samples_leaf=4, min_samples_split=10, n_estimators=100
# [CV 4/5; 324/324] END bootstrap=False, criterion=entropy, max_depth=20, min_samples_leaf=4, min_samples_split=10, n_estimators=100;, score=0.997 total time= 3.9min
# [CV 5/5; 324/324] START bootstrap=False, criterion=entropy, max_depth=20, min_samples_leaf=4, min_samples_split=10, n_estimators=100
# [CV 5/5; 324/324] END bootstrap=False, criterion=entropy, max_depth=20, min_samples_leaf=4, min_samples_split=10, n_estimators=100;, score=0.997 total time= 3.8min
# GridSearchCV(cv=5, estimator=RandomForestClassifier(random_state=42),
#              param_grid={'bootstrap': [True, False],
#                          'criterion': ['gini', 'entropy'],
#                          'max_depth': [None, 10, 20],
#                          'min_samples_leaf': [1, 2, 4],
#                          'min_samples_split': [2, 5, 10],
#                          'n_estimators': [10, 50, 100]},
#              scoring='accuracy', verbose=10)

# %%
# Get the best parameters and score
best_params = grid_search.best_params_
best_score = grid_search.best_score_

# %%
print("Best Parameters:", best_params)
print("Best Score:", best_score)
# Out:
# Best Parameters: {'bootstrap': False, 'criterion': 'entropy', 'max_depth': None, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 50}
# Best Score: 0.995631233676764

# %%
# Train the model with the best parameters
best_rfc = grid_search.best_estimator_

# %%
# Predictions
y_pred = best_rfc.predict(X_pca)

# %%
# Evaluate the model
accuracy = accuracy_score(y, y_pred)
precision = precision_score(y, y_pred, average='weighted')
recall = recall_score(y, y_pred, average='weighted')
f1 = f1_score(y, y_pred, average='weighted')

# %%
# Print evaluation metrics
print(f'Accuracy: {accuracy}')
print(f'Precision: {precision}')
print(f'Recall: {recall}')
print(f'F1 Score: {f1}')
# Out:
# Accuracy: 0.9999506447035598
# Precision: 0.9999506639476778
# Recall: 0.9999506447035598
# F1 Score: 0.9999506467722727
